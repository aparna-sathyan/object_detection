# %%
# !pip install ultralytics

# %%
import ultralytics

# %%
model=ultralytics.YOLO('yolov8s.pt')

# %%
! yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/trafficsigns/data.yaml epochs=20 batch=10 project=/content/drive/MyDrive/trafficsigns/results name=trafficsigns
# Out:
# Ultralytics 8.3.68 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
! yolo task=detect mode=predict model=/content/drive/MyDrive/trafficsigns/results/trafficsigns3/weights/best.pt conf=0.50 source=/content/drive/MyDrive/trafficsigns/test/images
# Out:
# Ultralytics 8.3.68 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/94 /content/drive/MyDrive/trafficsigns/test/images/29490_jpg.rf.5081257b845505575a847c6cd2525ed4.jpg: 640x640 1 1, 16.3ms
# image 2/94 /content/drive/MyDrive/trafficsigns/test/images/30440_jpg.rf.0975506354c7569a624b34832a15e0de.jpg: 640x640 1 0, 16.3ms
# image 3/94 /content/drive/MyDrive/trafficsigns/test/images/30450_jpg.rf.aef377b80f44e14fef5014c3b6ec61c7.jpg: 640x640 1 0, 16.3ms
# image 4/94 /content/drive/MyDrive/trafficsigns/test/images/32240_jpg.rf.eb90a716fb46e2b7b1a5a92e98878d1a.jpg: 640x640 1 0, 16.3ms
# image 5/94 /content/drive/MyDrive/trafficsigns/test/images/32380_jpg.rf.2fc3fa7a9832f4d5cc7fd01b4530979b.jpg: 640x640 2 0s, 16.3ms
# image 6/94 /content/drive/MyDrive/trafficsigns/test/images/38840_jpg.rf.c5978177467fdb13733673345fb4c8b3.jpg: 640x640 2 0s, 16.3ms
# ...

# %%
! cp -r /content/runs/detect/predict /content/drive/MyDrive/trafficsigns/output

# %%
! yolo task=detect mode=predict model=/content/drive/MyDrive/trafficsigns/results/trafficsigns3/weights/best.pt conf=0.50 source=/content/drive/MyDrive/trafficsigns/videotrafficsigns/ts.mp4
# Out:
# Ultralytics 8.3.68 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/490) /content/drive/MyDrive/trafficsigns/videotrafficsigns/ts.mp4: 640x384 (no detections), 38.4ms
# video 1/1 (frame 2/490) /content/drive/MyDrive/trafficsigns/videotrafficsigns/ts.mp4: 640x384 (no detections), 10.6ms
# video 1/1 (frame 3/490) /content/drive/MyDrive/trafficsigns/videotrafficsigns/ts.mp4: 640x384 (no detections), 10.6ms
# video 1/1 (frame 4/490) /content/drive/MyDrive/trafficsigns/videotrafficsigns/ts.mp4: 640x384 (no detections), 10.6ms
# video 1/1 (frame 5/490) /content/drive/MyDrive/trafficsigns/videotrafficsigns/ts.mp4: 640x384 (no detections), 10.6ms
# video 1/1 (frame 6/490) /content/drive/MyDrive/trafficsigns/videotrafficsigns/ts.mp4: 640x384 (no detections), 10.6ms
# ...

# %%
! cp -r /content/runs/detect/predict2 /content/drive/MyDrive/trafficsigns/voutput
