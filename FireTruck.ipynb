# %%
! pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.6/914.6 kB 22.0 MB/s eta 0:00:00
# ...

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=ultralytics.YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 99.2MB/s]

# %%
! yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/firetruck/data.yaml epochs=20 batch=10 project=/content/drive/MyDrive/firetruck/result name=firetruck
# Out:
# Ultralytics 8.3.69 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
! yolo task=detect mode=predict model=/content/drive/MyDrive/firetruck/result/firetruck/weights/best.pt conf=0.50 source=/content/drive/MyDrive/firetruck/test/images
# Out:
# Ultralytics 8.3.69 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/134 /content/drive/MyDrive/firetruck/test/images/100715-F-2988M-001-JPG_jpg.rf.254096f7df5edcd306d46e135834a99f.jpg: 640x640 1 fire truck, 16.2ms
# image 2/134 /content/drive/MyDrive/firetruck/test/images/2036131d1596032532-pics-fire-fighting-vehicles-india-emergency-rescue-1_jpg.rf.523e8e68d2984899b3530809aaaa6ee6.jpg: 640x640 1 fire truck, 16.4ms
# image 3/134 /content/drive/MyDrive/firetruck/test/images/Banner-pierce-quint-fire-truck-image_jpg.rf.26059a26795490b623d2cc7d0fc6b7b4.jpg: 640x640 1 fire truck, 16.3ms
# image 4/134 /content/drive/MyDrive/firetruck/test/images/DSC_1125_edit_jpg.rf.1945465bcff763d61f8817eab8dea5fa.jpg: 640x640 1 fire truck, 16.2ms
# ...

# %%
! cp -r /content/runs/detect/predict /content/drive/MyDrive/firetruck/output

# %%
! yolo task=detect mode=predict model=/content/drive/MyDrive/firetruck/result/firetruck/weights/best.pt conf=0.50 source=/content/drive/MyDrive/firetruck/video/ft.mp4
# Out:
# Ultralytics 8.3.69 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/538) /content/drive/MyDrive/firetruck/video/ft.mp4: 384x640 2 fire trucks, 39.8ms
# video 1/1 (frame 2/538) /content/drive/MyDrive/firetruck/video/ft.mp4: 384x640 2 fire trucks, 10.7ms
# video 1/1 (frame 3/538) /content/drive/MyDrive/firetruck/video/ft.mp4: 384x640 2 fire trucks, 10.7ms
# video 1/1 (frame 4/538) /content/drive/MyDrive/firetruck/video/ft.mp4: 384x640 2 fire trucks, 10.7ms
# video 1/1 (frame 5/538) /content/drive/MyDrive/firetruck/video/ft.mp4: 384x640 2 fire trucks, 10.7ms
# video 1/1 (frame 6/538) /content/drive/MyDrive/firetruck/video/ft.mp4: 384x640 2 fire trucks, 10.7ms
# video 1/1 (frame 7/538) /content/drive/MyDrive/firetruck/video/ft.mp4: 384x640 2 fire trucks, 10.7ms
# video 1/1 (frame 8/538) /content/drive/MyDrive/firetruck/video/ft.mp4: 384x640 2 fire trucks, 10.6ms
# ...

# %%
! cp -r /content/runs/detect/predict2 /content/drive/MyDrive/firetruck/Voutput
