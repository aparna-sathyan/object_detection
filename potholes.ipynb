# %%
! pip install ultralytics
import ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.6/913.6 kB 16.2 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=ultralytics.YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 140MB/s]

# %%
! yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/potholes/data.yaml epochs=20 batch=10 project=/content/drive/MyDrive/potholes/result name=potholes
# Out:
# Ultralytics 8.3.68 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
! yolo task=detect mode=predict model=/content/drive/MyDrive/potholes/result/potholes/weights/best.pt conf=0.50 source=/content/drive/MyDrive/potholes/test/images
# Out:
# Ultralytics 8.3.68 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/124 /content/drive/MyDrive/potholes/test/images/img-1.jpg: 640x640 1 pothole, 16.3ms
# image 2/124 /content/drive/MyDrive/potholes/test/images/img-1000.jpg: 384x640 1 pothole, 87.7ms
# image 3/124 /content/drive/MyDrive/potholes/test/images/img-103.jpg: 640x640 1 pothole, 18.5ms
# image 4/124 /content/drive/MyDrive/potholes/test/images/img-1037.jpg: 480x640 1 pothole, 71.7ms
# image 5/124 /content/drive/MyDrive/potholes/test/images/img-1038.jpg: 448x640 1 pothole, 51.6ms
# image 6/124 /content/drive/MyDrive/potholes/test/images/img-1042.jpg: 448x640 2 potholes, 13.0ms
# image 7/124 /content/drive/MyDrive/potholes/test/images/img-1053.jpg: 384x640 1 pothole, 12.2ms
# image 8/124 /content/drive/MyDrive/potholes/test/images/img-1057.jpg: 416x640 1 pothole, 54.1ms
# ...

# %%
! cp -r /content/runs/detect/predict /content/drive/MyDrive/potholes/output

# %%
! yolo task=detect mode=predict model=/content/drive/MyDrive/potholes/result/potholes/weights/best.pt conf=0.50 source=/content/drive/MyDrive/potholes/video/phs.mp4
# Out:
# Ultralytics 8.3.68 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/821) /content/drive/MyDrive/potholes/video/phs.mp4: 640x384 1 pothole, 66.8ms
# video 1/1 (frame 2/821) /content/drive/MyDrive/potholes/video/phs.mp4: 640x384 1 pothole, 10.7ms
# video 1/1 (frame 3/821) /content/drive/MyDrive/potholes/video/phs.mp4: 640x384 1 pothole, 10.7ms
# video 1/1 (frame 4/821) /content/drive/MyDrive/potholes/video/phs.mp4: 640x384 1 pothole, 10.6ms
# video 1/1 (frame 5/821) /content/drive/MyDrive/potholes/video/phs.mp4: 640x384 1 pothole, 10.9ms
# video 1/1 (frame 6/821) /content/drive/MyDrive/potholes/video/phs.mp4: 640x384 1 pothole, 10.7ms
# video 1/1 (frame 7/821) /content/drive/MyDrive/potholes/video/phs.mp4: 640x384 1 pothole, 10.6ms
# video 1/1 (frame 8/821) /content/drive/MyDrive/potholes/video/phs.mp4: 640x384 1 pothole, 10.6ms
# ...

# %%
! cp -r /content/runs/detect/predict2 /content/drive/MyDrive/potholes/Voutput
