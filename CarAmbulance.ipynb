# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.8/914.8 kB 52.7 MB/s eta 0:00:00
# ...

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=ultralytics.YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 64.3MB/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/carAmbulance/data.yaml epochs=20 batch=10 project=/content/drive/MyDrive/carAmbulance/result name=carAmbulance
# Out:
# Ultralytics 8.3.72 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/carAmbulance/result/carAmbulance/weights/best.pt conf=0.50 source=/content/drive/MyDrive/carAmbulance/test/images
# Out:
# Ultralytics 8.3.72 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/114 /content/drive/MyDrive/carAmbulance/test/images/001e6e78fbbbcdb4_jpg.rf.1fd9581aa0edce40ca3aa7184b00e609.jpg: 640x640 1 Car, 16.4ms
# image 2/114 /content/drive/MyDrive/carAmbulance/test/images/0037710c3d02f369_jpg.rf.b084b63722d15d4c478f2b203c5be28f.jpg: 640x640 2 Cars, 16.4ms
# image 3/114 /content/drive/MyDrive/carAmbulance/test/images/025e9c9069d42c5d_jpg.rf.f1513b3ebc3aa11b884140556a70aa1e.jpg: 640x640 1 Ambulance, 1 Car, 19.9ms
# image 4/114 /content/drive/MyDrive/carAmbulance/test/images/045e6da6fd7f6fb0_jpg.rf.dd1abeaa14544f68268f63dc72257a26.jpg: 640x640 1 Ambulance, 16.3ms
# image 5/114 /content/drive/MyDrive/carAmbulance/test/images/05262f9d8b53f9cb_jpg.rf.356caf242ec943cf1e286d99428f322b.jpg: 640x640 2 Cars, 17.4ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/carAmbulance/output

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/carAmbulance/result/carAmbulance/weights/best.pt conf=0.50 source=/content/drive/MyDrive/carAmbulance/video/amandca.mp4
# Out:
# Ultralytics 8.3.72 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/417) /content/drive/MyDrive/carAmbulance/video/amandca.mp4: 384x640 1 Car, 43.7ms
# video 1/1 (frame 2/417) /content/drive/MyDrive/carAmbulance/video/amandca.mp4: 384x640 2 Cars, 10.7ms
# video 1/1 (frame 3/417) /content/drive/MyDrive/carAmbulance/video/amandca.mp4: 384x640 1 Car, 10.7ms
# video 1/1 (frame 4/417) /content/drive/MyDrive/carAmbulance/video/amandca.mp4: 384x640 1 Car, 10.8ms
# video 1/1 (frame 5/417) /content/drive/MyDrive/carAmbulance/video/amandca.mp4: 384x640 1 Car, 10.6ms
# video 1/1 (frame 6/417) /content/drive/MyDrive/carAmbulance/video/amandca.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (frame 7/417) /content/drive/MyDrive/carAmbulance/video/amandca.mp4: 384x640 2 Cars, 13.7ms
# ...

# %%
# !cp -r /content/runs/detect/predict4 /content/drive/MyDrive/carAmbulance/voutput
