# %%
! pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 23.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 54.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 97.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=ultralytics.YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 273MB/s]

# %%
! yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/SpeedBump/data.yaml epochs=20 batch=10 project=/content/drive/MyDrive/SpeedBump/result name=speedbump
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/SpeedBump/result/speedbump2/weights/best.pt conf=0.50 source=/content/drive/MyDrive/SpeedBump/test/images
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/96 /content/drive/MyDrive/SpeedBump/test/images/0_jpg.rf.a262ea6f125a780db7662150dfdde1fc.jpg: 640x640 1 speed bump, 16.3ms
# image 2/96 /content/drive/MyDrive/SpeedBump/test/images/10_jpg.rf.dcbb1914035436cdc80573b6967442e6.jpg: 640x640 (no detections), 16.3ms
# image 3/96 /content/drive/MyDrive/SpeedBump/test/images/1122_jpg.rf.391e51de38a50741f6140752fea23ee8.jpg: 640x640 1 speed bump, 16.3ms
# image 4/96 /content/drive/MyDrive/SpeedBump/test/images/1168_jpg.rf.cce7a12e0d8a4574a61fc260ee89a95b.jpg: 640x640 1 speed bump, 16.3ms
# image 5/96 /content/drive/MyDrive/SpeedBump/test/images/1189_jpg.rf.3146cd0184f5e583a5ddba769abb4f9c.jpg: 640x640 1 speed bump, 16.4ms
# image 6/96 /content/drive/MyDrive/SpeedBump/test/images/1214_jpg.rf.a51db205f76465685f7de7a728b430cd.jpg: 640x640 1 speed bump, 16.3ms
# ...

# %%
! cp -r /content/runs/detect/predict /content/drive/MyDrive/SpeedBump/output

# %%
! yolo task=detect mode=predict model=/content/drive/MyDrive/SpeedBump/result/speedbump2/weights/best.pt conf=0.50 source=/content/drive/MyDrive/SpeedBump/video/sb.mp4
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/702) /content/drive/MyDrive/SpeedBump/video/sb.mp4: 384x640 1 speed bump, 39.4ms
# video 1/1 (frame 2/702) /content/drive/MyDrive/SpeedBump/video/sb.mp4: 384x640 1 speed bump, 10.8ms
# video 1/1 (frame 3/702) /content/drive/MyDrive/SpeedBump/video/sb.mp4: 384x640 1 speed bump, 10.6ms
# video 1/1 (frame 4/702) /content/drive/MyDrive/SpeedBump/video/sb.mp4: 384x640 1 speed bump, 10.7ms
# video 1/1 (frame 5/702) /content/drive/MyDrive/SpeedBump/video/sb.mp4: 384x640 1 speed bump, 11.8ms
# video 1/1 (frame 6/702) /content/drive/MyDrive/SpeedBump/video/sb.mp4: 384x640 1 speed bump, 10.6ms
# video 1/1 (frame 7/702) /content/drive/MyDrive/SpeedBump/video/sb.mp4: 384x640 1 speed bump, 10.7ms
# video 1/1 (frame 8/702) /content/drive/MyDrive/SpeedBump/video/sb.mp4: 384x640 1 speed bump, 10.7ms
# ...

# %%
! cp -r /content/runs/detect/predict2 /content/drive/MyDrive/SpeedBump/voutput
